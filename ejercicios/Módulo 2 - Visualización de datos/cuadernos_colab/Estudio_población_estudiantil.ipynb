# %%
import pandas as pd

# %% [markdown]
# Obtener el fichero de datos

# %%
df = pd.read_csv('http://fpaniaguapython.github.io/datos/encuesta_poblacion.csv')
df
# Out:
#                     Marca temporal  Nombre y apellidos               Género  \
# 0   2026/05/08 11:48:31 a. m. EEST       Tom Rodríguez               Hombre
# 1   2026/05/08 11:50:30 a. m. EEST        Laura Martín                Mujer
# 2   2026/05/08 11:50:33 a. m. EEST      Michelle Smith                Mujer
# 3   2026/05/08 11:51:01 a. m. EEST      Gerardo Cruise               Hombre
# 4   2026/05/08 11:51:19 a. m. EEST         Oz De Armas               Hombre
# 5   2026/05/08 11:51:38 a. m. EEST      Maria Martinez                Mujer
# 6   2026/05/08 11:51:57 a. m. EEST  MISTERIO INCOGNITO               Hombre
# 7   2026/05/08 11:52:11 a. m. EEST    Pablo Lopez Polo               Hombre
# 8   2026/05/08 11:52:19 a. m. EEST         Liseth leon                Mujer
# 9   2026/05/08 11:52:22 a. m. EEST               Marta                Mujer
# 10  2026/05/08 11:52:42 a. m. EEST       Diego Jiménez  Prefiero no decirlo
# 11  2026/05/08 11:52:50 a. m. EEST       Jorge Semprún               Hombre
# 12  2026/05/08 11:53:14 a. m. EEST         Bruce Wayne               Hombre
# 13  2026/05/08 11:51:38 a. m. EEST      Maria Martinez                Mujer
# 14  2026/05/08 11:55:44 a. m. EEST        Jorge Vargas               Hombre
# 15  2026/05/08 11:56:07 a. m. EEST        Beto Aguirre               Hombre
#
#    Fecha de nacimiento Altura   Peso  Número de hijos  Grado de felicidad
# 0           1971-05-21    170   90.0              0.0                   4
# 1           1994-09-06    165   62.0              NaN                   5
# 2           1999-05-27   1.60   65.1              0.0                   3
# 3           1962-02-21   1,75   85.0              2.0                   4
# 4           1971-10-02    179   93.0              2.0                   4
# 5           1984-02-19   1.75   75.0              0.0                   4
# 6           1975-10-01    190   90.0              1.0                  -3
# 7           2005-03-20   1,80   70.0              1.0                   4
# 8           2000-12-31   1,61   56.0              0.0                   3
# 9           1985-12-01    160   65.0              2.0                   5
# 10          2003-12-29    184   70.0              0.0                   4
# 11          2000-05-22   1.73   57.0              0.0                   4
# 12                 NaN    188    NaN              0.0                   1
# 13          1984-02-19   1.75   75.0              0.0                   4
# 14          1846-02-18   4.50  156.0             12.0                   5
# 15          1991-12-20   1.94   80.0              6.0                   1

# %% [markdown]
# Mostrar la estructura del df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marca temporal       16 non-null     object
#  1   Nombre y apellidos   16 non-null     object
#  2   Género               16 non-null     object
#  3   Fecha de nacimiento  15 non-null     object
#  4   Altura               16 non-null     object
#  5   Peso                 15 non-null     float64
#  6   Número de hijos      15 non-null     float64
#  7   Grado de felicidad   16 non-null     int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.1+ KB

# %% [markdown]
# Mostrar los nombres de las columnas

# %%
df.columns
# Out:
# Index(['Marca temporal', 'Nombre y apellidos', 'Género', 'Fecha de nacimiento',
#        'Altura', 'Peso', 'Número de hijos', 'Grado de felicidad'],
#       dtype='object')

# %% [markdown]
# Cambiar los nombres de las columnas

# %%
df.columns = ['timestamp', 'nombre', 'genero', 'fecha', 'altura', 'peso', 'hijos', 'felicidad']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  16 non-null     object
#  1   nombre     16 non-null     object
#  2   genero     16 non-null     object
#  3   fecha      15 non-null     object
#  4   altura     16 non-null     object
#  5   peso       15 non-null     float64
#  6   hijos      15 non-null     float64
#  7   felicidad  16 non-null     int64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 1.1+ KB

# %% [markdown]
# Anonimizar los datos

# %%
df['nombre']='Sujeto'
df.head() # Muestra los 5 primeros registros
# Out:
#                         timestamp  nombre  genero       fecha altura  peso  \
# 0  2026/05/08 11:48:31 a. m. EEST  Sujeto  Hombre  1971-05-21    170  90.0
# 1  2026/05/08 11:50:30 a. m. EEST  Sujeto   Mujer  1994-09-06    165  62.0
# 2  2026/05/08 11:50:33 a. m. EEST  Sujeto   Mujer  1999-05-27   1.60  65.1
# 3  2026/05/08 11:51:01 a. m. EEST  Sujeto  Hombre  1962-02-21   1,75  85.0
# 4  2026/05/08 11:51:19 a. m. EEST  Sujeto  Hombre  1971-10-02    179  93.0
#
#    hijos  felicidad
# 0    0.0          4
# 1    NaN          5
# 2    0.0          3
# 3    2.0          4
# 4    2.0          4

# %% [markdown]
# Unificar las unidades de la altura

# %%
df['altura']=df['altura'].str.replace(',','')
df['altura']=df['altura'].str.replace('.','')
df.head()
# Out:
#                         timestamp  nombre  genero       fecha altura  peso  \
# 0  2026/05/08 11:48:31 a. m. EEST  Sujeto  Hombre  1971-05-21    170  90.0
# 1  2026/05/08 11:50:30 a. m. EEST  Sujeto   Mujer  1994-09-06    165  62.0
# 2  2026/05/08 11:50:33 a. m. EEST  Sujeto   Mujer  1999-05-27    160  65.1
# 3  2026/05/08 11:51:01 a. m. EEST  Sujeto  Hombre  1962-02-21    175  85.0
# 4  2026/05/08 11:51:19 a. m. EEST  Sujeto  Hombre  1971-10-02    179  93.0
#
#    hijos  felicidad
# 0    0.0          4
# 1    NaN          5
# 2    0.0          3
# 3    2.0          4
# 4    2.0          4

# %% [markdown]
# Convertir de la altura a número (porque es un str)

# %%
df['altura']=pd.to_numeric(df['altura'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  16 non-null     object
#  1   nombre     16 non-null     object
#  2   genero     16 non-null     object
#  3   fecha      15 non-null     object
#  4   altura     16 non-null     int64
#  5   peso       15 non-null     float64
#  6   hijos      15 non-null     float64
#  7   felicidad  16 non-null     int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# Tratar los nulos de la columna peso

# %%
# df['peso'] = df['peso'].fillna(0) # Asignamos 0 a los pesos nulos
# df['peso'] = df['peso'].fillna(100) # Asignamos 100 a los pesos nulos
# df = df.dropna(subset=['peso']) # Eliminar los registros cuyos pesos sean nulos
df['peso'] = df['peso'].fillna(df['peso'].mean())
df
# Out:
#                          timestamp  nombre               genero       fecha  \
# 0   2026/05/08 11:48:31 a. m. EEST  Sujeto               Hombre  1971-05-21
# 1   2026/05/08 11:50:30 a. m. EEST  Sujeto                Mujer  1994-09-06
# 2   2026/05/08 11:50:33 a. m. EEST  Sujeto                Mujer  1999-05-27
# 3   2026/05/08 11:51:01 a. m. EEST  Sujeto               Hombre  1962-02-21
# 4   2026/05/08 11:51:19 a. m. EEST  Sujeto               Hombre  1971-10-02
# 5   2026/05/08 11:51:38 a. m. EEST  Sujeto                Mujer  1984-02-19
# 6   2026/05/08 11:51:57 a. m. EEST  Sujeto               Hombre  1975-10-01
# 7   2026/05/08 11:52:11 a. m. EEST  Sujeto               Hombre  2005-03-20
# 8   2026/05/08 11:52:19 a. m. EEST  Sujeto                Mujer  2000-12-31
# 9   2026/05/08 11:52:22 a. m. EEST  Sujeto                Mujer  1985-12-01
# 10  2026/05/08 11:52:42 a. m. EEST  Sujeto  Prefiero no decirlo  2003-12-29
# 11  2026/05/08 11:52:50 a. m. EEST  Sujeto               Hombre  2000-05-22
# 12  2026/05/08 11:53:14 a. m. EEST  Sujeto               Hombre         NaN
# 13  2026/05/08 11:51:38 a. m. EEST  Sujeto                Mujer  1984-02-19
# 14  2026/05/08 11:55:44 a. m. EEST  Sujeto               Hombre  1846-02-18
# 15  2026/05/08 11:56:07 a. m. EEST  Sujeto               Hombre  1991-12-20
#
#     altura        peso  hijos  felicidad
# 0      170   90.000000    0.0          4
# 1      165   62.000000    NaN          5
# 2      160   65.100000    0.0          3
# 3      175   85.000000    2.0          4
# 4      179   93.000000    2.0          4
# 5      175   75.000000    0.0          4
# 6      190   90.000000    1.0         -3
# 7      180   70.000000    1.0          4
# 8      161   56.000000    0.0          3
# 9      160   65.000000    2.0          5
# 10     184   70.000000    0.0          4
# 11     173   57.000000    0.0          4
# 12     188   79.273333    0.0          1
# 13     175   75.000000    0.0          4
# 14     450  156.000000   12.0          5
# 15     194   80.000000    6.0          1

# %% [markdown]
# # Tratar los NaN

# %%
# df = df.dropna() # Eliminar todos los registros con algún campo NaN o NaD
df = df.dropna(subset=['fecha']).copy() # Eliminamos los registros con el campo fecha NaN o NaD
# df['hijos'] = df['hijos'].fillna(0) # Asignamos la mediana
df['hijos'] = df['hijos'].fillna(df['hijos'].median()) # Asignamos la mediana
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 0 to 15
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  15 non-null     object
#  1   nombre     15 non-null     object
#  2   genero     15 non-null     object
#  3   fecha      15 non-null     object
#  4   altura     15 non-null     int64
#  5   peso       15 non-null     float64
#  6   hijos      15 non-null     float64
#  7   felicidad  15 non-null     int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.1+ KB

# %% [markdown]
# # Calcular el IMC

# %%
df['IMC']=df['peso']/((df['altura']/100)**2)
df.head()
# Out:
#                         timestamp  nombre  genero       fecha  altura  peso  \
# 0  2026/05/08 11:48:31 a. m. EEST  Sujeto  Hombre  1971-05-21     170  90.0
# 1  2026/05/08 11:50:30 a. m. EEST  Sujeto   Mujer  1994-09-06     165  62.0
# 2  2026/05/08 11:50:33 a. m. EEST  Sujeto   Mujer  1999-05-27     160  65.1
# 3  2026/05/08 11:51:01 a. m. EEST  Sujeto  Hombre  1962-02-21     175  85.0
# 4  2026/05/08 11:51:19 a. m. EEST  Sujeto  Hombre  1971-10-02     179  93.0
#
#    hijos  felicidad        IMC
# 0    0.0          4  31.141869
# 1    0.5          5  22.773186
# 2    0.0          3  25.429687
# 3    2.0          4  27.755102
# 4    2.0          4  29.025311

# %%
import matplotlib.pyplot as plt
plt.plot(df['altura'])

# %% [markdown]
# # Eliminar outliers

# %%
df = df[df['altura'] < 250]
plt.plot(df['IMC'])

# %% [markdown]
# # Reasignar los índices

# %%
df.reset_index(inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %% [markdown]
# Obtener la media de hijos de los hombres de la colección

# %%
df_hombres = df[df['genero'] == 'Hombre']
media_hijos_hombres = df_hombres['hijos'].mean()
media_hijos_hombres
# Out:
# np.float64(1.7142857142857142)
